# %% [markdown]
# # DLThon CV - Motorcycle Night Ride Semantic Segmentation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab\ Notebooks/aiffel/MainProject3/motorcycle_night_ride
# Out:
# /content/drive/MyDrive/Colab Notebooks/aiffel/MainProject3/motorcycle_night_ride

# %%
import os
import cv2
import random
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

from tensorflow import keras
from tensorflow.keras import layers, models, Input, Model, optimizers, utils, backend

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
# !kaggle datasets download -d sadhliroomyprime/motorcycle-night-ride-semantic-segmentation
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/opt/conda/lib/python3.9/site-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/opt/conda/lib/python3.9/site-packages/kaggle/api/kaggle_api_extended.py", line 403, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /aiffel/.kaggle. Or use the environment method.

# %%
# !unzip motorcycle-night-ride-semantic-segmentation.zip
# Out:
# unzip:  cannot find or open motorcycle-night-ride-semantic-segmentation.zip, motorcycle-night-ride-semantic-segmentation.zip.zip or motorcycle-night-ride-semantic-segmentation.zip.ZIP.

# %% [markdown]
# ### (1) Motorcycle Night Ride 데이터셋 전처리

# %% [markdown]
# - Dataset Load, Augmentation을 위한 패키지 다운로드

# %%
# !pip install pycocotools
# !pip install albumentations
# Out:
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.11.2)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.19.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.8.0.76)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations) (4.5.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2.31.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (2023.8.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations) (23.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.2.0)

# %% [markdown]
# - Augmentation

# %%
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

def build_augmentation(is_train=True):
    if is_train:    # 훈련용 데이터일 경우
        return Compose([
                    HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                    RandomSizedCrop(          # 50%의 확률로 RandomSizedCrop
                        min_max_height=(300, 370),
                        w2h_ratio=370/1242,
                        height=224,
                        width=224,
                        p=0.5
                        ),
                    Resize(                   # 입력이미지를 224X224로 resize
                        width=224,
                        height=224
                        )
                    ])
    return Compose([      # 테스트용 데이터는 224X224로 resize만 수행
                Resize(
                    width=224,
                    height=224
                    )
                ])

# %% [markdown]
# - Data Generator

# %%
from pycocotools.coco import COCO

class CustomDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, coco_ann_file, image_dir, class_id_to_name, idx, batch_size=32, shuffle=True, hist=False, augmentation=True):
        self.coco = COCO(coco_ann_file)
        self.image_dir = image_dir
        self.class_id_to_name = class_id_to_name
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.hist = hist
        self.image_ids = list(idx)
        self.indexes = np.arange(len(self.image_ids))
        self.augmentation = augmentation
        if self.shuffle:
            random.shuffle(self.indexes)

    def __len__(self):
        return int(np.ceil(len(self.image_ids) / self.batch_size))

    def __getitem__(self, index):
        batch_indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        batch_data = []             # batch_size 만큼의 X
        batch_masks = []            # batch_size 만큼의 Y

        for idx in batch_indexes:
            image_info = self.coco.loadImgs(self.image_ids[idx])[0]
            image_path = os.path.join(self.image_dir, image_info['file_name'])  # 이미지 파일 경로
            image = cv2.imread(image_path)                                      # 이미지 불러오기

            if self.hist:
                src_ycrcb = cv2.cvtColor(image, cv2.COLOR_RGB2YCrCb)
                ycrcb_planes = cv2.split(src_ycrcb)

                # 밝기 성분에 대해서만 히스토그램 평활화 수행
                ycrcb_planes[0] = cv2.equalizeHist(ycrcb_planes[0])

                dst_ycrcb = cv2.merge(ycrcb_planes)
                image = cv2.cvtColor(dst_ycrcb, cv2.COLOR_YCrCb2RGB)                # 이미지 hist equalize

            image_height, image_width, _ = image.shape                          # 이미지 shape

            # 이미지 annotation 정보
            annotation_ids = self.coco.getAnnIds(imgIds=image_info['id'])
            annotations_info = self.coco.loadAnns(annotation_ids)

            multi_class_mask = np.zeros((image_height, image_width, len(self.class_id_to_name)), dtype=np.uint8)

            # 각 어노테이션 정보를 이용하여 멀티클래스 객체 마스크를 생성
            for annotation_info in annotations_info:
                if 'segmentation' in annotation_info and 'category_id' in annotation_info:
                    segmentation = annotation_info['segmentation']
                    segmentation = [int(x) for x in segmentation[0]]            # 세그멘테이션 좌표
                    class_id = annotation_info['category_id']

                    # 클래스 ID를 이용하여 채널 인덱스 결정
                    channel_index = list(self.class_id_to_name.keys()).index(class_id)

                    # 세그멘테이션 좌표를 이미지 경계에 맞게 자르기
                    segmentation = [min(max(coord, 0), image_height - 1) for coord in segmentation[::2]]
                    segmentation = [min(max(coord, 0), image_width - 1) for coord in segmentation[1::2]]

                    # 마스크 생성 및 클래스 색상 설정
                    mask = self.coco.annToMask(annotation_info) * 255

                    # 마스크 영역을 클래스 색상으로 채우고 마스크를 멀티클래스 마스크에 추가
                    multi_class_mask[mask > 0, channel_index] = 255

                data = {
                "image": np.array(image),
                "mask" : np.array(multi_class_mask)
            }

            # Augmentation
            augmented = self.augmentation(**data)

            # Normalization
            image = augmented["image"]/255
            multi_class_mask = augmented["mask"]/255

            batch_data.append(image)
            batch_masks.append(multi_class_mask)

        return np.array(batch_data), np.array(batch_masks)

    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.indexes)

# %% [markdown]
# - train test split

# %%
import numpy as np

# 랜덤 시드 설정
np.random.seed(1004)

# 데이터 인덱스 생성
image_idx = list(range(1,201)) # 데이터의 인덱스 리스트

# 데이터를 train과 test로 나누기
test_ratio = 0.2  # 테스트 세트의 비율 (예: 20%)
num_test = int(len(image_idx) * test_ratio)  # 테스트 세트의 크기
test_idx = np.random.choice(image_idx, size=num_test, replace=False)  # 테스트 세트의 인덱스 선택

# 나머지 인덱스는 훈련 세트로 사용
train_idx = np.setdiff1d(image_idx, test_idx)

# int type list로 변환
train_idx = train_idx.astype('int32').tolist()
test_idx = test_idx.astype('int32').tolist()

# %% [markdown]
# - Train, Test data 생성

# %%
coco_ann_file = './data/COCO_motorcycle.json'  # COCO 어노테이션 파일 경로
image_dir = './data/images/'  # 이미지 디렉토리 경로
class_id_to_name = {  # 클래스 정보 정의
    1329681: 'Rider',
    1323885: 'My bike',
    1323884: 'Moveable',
    1323882: 'Lane Mark',
    1323881: 'Road',
    1323880: 'Undrivable',
}

batch_size = 5  # 배치 크기

# %%
# COCO 객체 생성
coco = COCO(coco_ann_file)

# 이미지, 어노테이션, 클래스 정보 추출
images = coco.dataset['images']
annotations = coco.dataset['annotations']
categories = coco.dataset['categories']
# Out:
# loading annotations into memory...
# Done (t=6.36s)
# creating index...
# index created!

# %%
# augmentation 객체 생성
train_preproc = build_augmentation(is_train=False)
test_preproc = build_augmentation(is_train=False)

# %%
# train, test data generator 생성
train_data_generator = CustomDataGenerator(coco_ann_file, image_dir, class_id_to_name, train_idx ,batch_size, True, False, train_preproc)
# train_hist_data_generator = CustomDataGenerator(coco_ann_file, image_dir, class_id_to_name, train_idx ,batch_size, True, True, train_preproc)
test_data_generator = CustomDataGenerator(coco_ann_file, image_dir, class_id_to_name, test_idx ,batch_size, False, False, test_preproc)
# Out:
# loading annotations into memory...
# Done (t=2.56s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=3.45s)
# creating index...
# index created!

# %% [markdown]
# - 배치 데이터 확인

# %%
for epoch in range(1):
    for batch_data, batch_masks in train_data_generator:
        print(batch_data.shape, batch_masks.shape)
        plt.figure(figsize=(12, 6))

        plt.subplot(2, 4, 1)
        plt.imshow(batch_data[0])

        for i in range(6):
            plt.subplot(2, 4, i+3)
            plt.imshow(batch_masks[0, :, :, i])

        plt.show()
        break
# Out:
# (5, 224, 224, 3) (5, 224, 224, 6)

# %% [markdown]
# ### (2) Baseline 모델 구현

# %% [markdown]
# segmentation task 이기에 가장 기본이 되는 U-Net을 Baseline model로 선정하였다.

# %%
def conv_block(inputs, n_filters):
    x = layers.Conv2D(n_filters, 3, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    return x

# %%
def down_block(inputs, n_filters):
    x = conv_block(inputs, n_filters)
    x = conv_block(x, n_filters)
    d = layers.MaxPooling2D((2, 2))(x)

    return x, d

# %%
def up_block(inputs, skip_list, n_filters):
    u = layers.Conv2DTranspose(n_filters, (2, 2), strides=2, padding='same')(inputs)
    x = layers.Concatenate()(skip_list + [u])
    x = conv_block(x, n_filters)
    x = conv_block(x, n_filters)

    return x

# %%
def UNET(n_classes=1, input_shape=(224, 224, 3)):
    inputs = Input(shape=input_shape)
    output_size = [64, 128, 256, 512, 1024]

    x00, d = down_block(inputs, output_size[0])

    x10, d = down_block(d, output_size[1])

    x20, d = down_block(d, output_size[2])

    x30, d = down_block(d, output_size[3])

    x40, _ = down_block(d, output_size[4])
    x31 = up_block(x40, [x30], output_size[3])
    x22 = up_block(x31, [x20], output_size[2])
    x13 = up_block(x22, [x10], output_size[1])
    x04 = up_block(x13, [x00], output_size[0])

    if n_classes == 1:
        x = layers.Conv2D(n_classes, 1, padding='same', activation='sigmoid')(x04)
    else:
        x = layers.Conv2D(n_classes, 1, padding='same', activation='softmax')(x04)

    return Model(inputs, x, name='U-Net')

# %% [markdown]
# - U-Net Summary

# %%
model_unet = UNET(input_shape=(224,224,3))
model_unet.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_53 (Conv2D)          (None, 224, 224, 64)         1792      ['input_3[0][0]']
#
#  batch_normalization_48 (Ba  (None, 224, 224, 64)         256       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 224, 224, 64)         36928     ['activation_48[0][0]']
#
#  batch_normalization_49 (Ba  (None, 224, 224, 64)         256       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  max_pooling2d_10 (MaxPooli  (None, 112, 112, 64)         0         ['activation_49[0][0]']
#  ng2D)
#
#  conv2d_55 (Conv2D)          (None, 112, 112, 128)        73856     ['max_pooling2d_10[0][0]']
#
#  batch_normalization_50 (Ba  (None, 112, 112, 128)        512       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 112, 112, 128)        0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_56 (Conv2D)          (None, 112, 112, 128)        147584    ['activation_50[0][0]']
#
#  batch_normalization_51 (Ba  (None, 112, 112, 128)        512       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 112, 112, 128)        0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  max_pooling2d_11 (MaxPooli  (None, 56, 56, 128)          0         ['activation_51[0][0]']
#  ng2D)
#
#  conv2d_57 (Conv2D)          (None, 56, 56, 256)          295168    ['max_pooling2d_11[0][0]']
#
#  batch_normalization_52 (Ba  (None, 56, 56, 256)          1024      ['conv2d_57[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 56, 56, 256)          0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 56, 56, 256)          590080    ['activation_52[0][0]']
#
#  batch_normalization_53 (Ba  (None, 56, 56, 256)          1024      ['conv2d_58[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 56, 56, 256)          0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  max_pooling2d_12 (MaxPooli  (None, 28, 28, 256)          0         ['activation_53[0][0]']
#  ng2D)
#
#  conv2d_59 (Conv2D)          (None, 28, 28, 512)          1180160   ['max_pooling2d_12[0][0]']
#
#  batch_normalization_54 (Ba  (None, 28, 28, 512)          2048      ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 28, 28, 512)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 28, 28, 512)          2359808   ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 28, 28, 512)          2048      ['conv2d_60[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 28, 28, 512)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  max_pooling2d_13 (MaxPooli  (None, 14, 14, 512)          0         ['activation_55[0][0]']
#  ng2D)
#
#  conv2d_61 (Conv2D)          (None, 14, 14, 1024)         4719616   ['max_pooling2d_13[0][0]']
#
#  batch_normalization_56 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_61[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 14, 14, 1024)         0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_62 (Conv2D)          (None, 14, 14, 1024)         9438208   ['activation_56[0][0]']
#
#  batch_normalization_57 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_62[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 14, 14, 1024)         0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  conv2d_transpose_14 (Conv2  (None, 28, 28, 512)          2097664   ['activation_57[0][0]']
#  DTranspose)
#
#  concatenate_14 (Concatenat  (None, 28, 28, 1024)         0         ['activation_55[0][0]',
#  e)                                                                  'conv2d_transpose_14[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 28, 28, 512)          4719104   ['concatenate_14[0][0]']
#
#  batch_normalization_58 (Ba  (None, 28, 28, 512)          2048      ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 28, 28, 512)          0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  conv2d_64 (Conv2D)          (None, 28, 28, 512)          2359808   ['activation_58[0][0]']
#
#  batch_normalization_59 (Ba  (None, 28, 28, 512)          2048      ['conv2d_64[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 28, 28, 512)          0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_transpose_15 (Conv2  (None, 56, 56, 256)          524544    ['activation_59[0][0]']
#  DTranspose)
#
#  concatenate_15 (Concatenat  (None, 56, 56, 512)          0         ['activation_53[0][0]',
#  e)                                                                  'conv2d_transpose_15[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 56, 56, 256)          1179904   ['concatenate_15[0][0]']
#
#  batch_normalization_60 (Ba  (None, 56, 56, 256)          1024      ['conv2d_65[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 56, 56, 256)          0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  conv2d_66 (Conv2D)          (None, 56, 56, 256)          590080    ['activation_60[0][0]']
#
#  batch_normalization_61 (Ba  (None, 56, 56, 256)          1024      ['conv2d_66[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 56, 56, 256)          0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_transpose_16 (Conv2  (None, 112, 112, 128)        131200    ['activation_61[0][0]']
#  DTranspose)
#
#  concatenate_16 (Concatenat  (None, 112, 112, 256)        0         ['activation_51[0][0]',
#  e)                                                                  'conv2d_transpose_16[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 112, 112, 128)        295040    ['concatenate_16[0][0]']
#
#  batch_normalization_62 (Ba  (None, 112, 112, 128)        512       ['conv2d_67[0][0]']
#  tchNormalization)
#
#  activation_62 (Activation)  (None, 112, 112, 128)        0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  conv2d_68 (Conv2D)          (None, 112, 112, 128)        147584    ['activation_62[0][0]']
#
#  batch_normalization_63 (Ba  (None, 112, 112, 128)        512       ['conv2d_68[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 112, 112, 128)        0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_transpose_17 (Conv2  (None, 224, 224, 64)         32832     ['activation_63[0][0]']
#  DTranspose)
#
#  concatenate_17 (Concatenat  (None, 224, 224, 128)        0         ['activation_49[0][0]',
#  e)                                                                  'conv2d_transpose_17[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 224, 224, 64)         73792     ['concatenate_17[0][0]']
#
#  batch_normalization_64 (Ba  (None, 224, 224, 64)         256       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv2d_70 (Conv2D)          (None, 224, 224, 64)         36928     ['activation_64[0][0]']
#
#  batch_normalization_65 (Ba  (None, 224, 224, 64)         256       ['conv2d_70[0][0]']
#  tchNormalization)
#
#  activation_65 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_71 (Conv2D)          (None, 224, 224, 1)          65        ['activation_65[0][0]']
#
# ==================================================================================================
# Total params: 31055297 (118.47 MB)
# Trainable params: 31043521 (118.42 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### (3) U-Net++ 모델 구현

# %% [markdown]
# 성능 향상을 위해 skip connection이 여럿 추가된 U-Net++를 비교 모델로 선택하였다.

# %%
def UNETPP(n_classes=6, input_shape=(224, 224, 3), deep_supervision=False):
    inputs = Input(shape=input_shape)
    output_size = [64, 128, 256, 512, 1024]

    x00, d = down_block(inputs, output_size[0])

    x10, d = down_block(d, output_size[1])
    x01 = up_block(x10, [x00], output_size[0])

    x20, d = down_block(d, output_size[2])
    x11 = up_block(x20, [x10], output_size[0])
    x02 = up_block(x11, [x00, x01], output_size[0])

    x30, d = down_block(d, output_size[3])
    x21 = up_block(x30, [x20], output_size[0])
    x12 = up_block(x21, [x10, x11], output_size[0])
    x03 = up_block(x12, [x00, x01, x02], output_size[0])

    x40, _ = down_block(d, output_size[4])
    x31 = up_block(x40, [x30], output_size[3])
    x22 = up_block(x31, [x20, x21], output_size[2])
    x13 = up_block(x22, [x10, x11, x12], output_size[1])
    x04 = up_block(x13, [x00, x01, x02, x03], output_size[0])

    x1 = layers.Conv2D(n_classes, 1, padding='same', activation='sigmoid')(x01)
    x2 = layers.Conv2D(n_classes, 1, padding='same', activation='sigmoid')(x02)
    x3 = layers.Conv2D(n_classes, 1, padding='same', activation='sigmoid')(x03)
    x4 = layers.Conv2D(n_classes, 1, padding='same', activation='sigmoid')(x04)

    if deep_supervision:
        x = [x1, x2, x3, x4]
    else:
        x = [x4]

    return Model(inputs, x, name='U-NetPP-D') if deep_supervision else Model(inputs, x, name='U-NetPP')

# %% [markdown]
# - U-Net++ Summary

# %%
model_unetpp = UNETPP(input_shape=(224,224,3))
model_unetpp.summary()
# Out:
# Model: "U-NetPP"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_19 (Conv2D)          (None, 224, 224, 64)         1792      ['input_2[0][0]']
#
#  batch_normalization_18 (Ba  (None, 224, 224, 64)         256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 224, 224, 64)         36928     ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 224, 224, 64)         256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 112, 112, 64)         0         ['activation_19[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 112, 112, 128)        73856     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_20 (Ba  (None, 112, 112, 128)        512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 112, 112, 128)        0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 112, 112, 128)        147584    ['activation_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 112, 112, 128)        512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 112, 112, 128)        0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, 56, 56, 128)          0         ['activation_21[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 56, 56, 256)          295168    ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (Ba  (None, 56, 56, 256)          1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 56, 56, 256)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 56, 56, 256)          590080    ['activation_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 56, 56, 256)          1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 56, 56, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 28, 28, 256)          0         ['activation_25[0][0]']
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 512)          1180160   ['max_pooling2d_7[0][0]']
#
#  batch_normalization_30 (Ba  (None, 28, 28, 512)          2048      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 28, 28, 512)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 512)          2359808   ['activation_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 28, 28, 512)          2048      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 28, 28, 512)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 14, 512)          0         ['activation_31[0][0]']
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 1024)         4719616   ['max_pooling2d_8[0][0]']
#
#  batch_normalization_38 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 14, 14, 1024)         0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 1024)         9438208   ['activation_38[0][0]']
#
#  batch_normalization_39 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 14, 14, 1024)         0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_transpose_10 (Conv2  (None, 28, 28, 512)          2097664   ['activation_39[0][0]']
#  DTranspose)
#
#  conv2d_transpose_7 (Conv2D  (None, 56, 56, 64)           131136    ['activation_31[0][0]']
#  Transpose)
#
#  concatenate_10 (Concatenat  (None, 28, 28, 1024)         0         ['activation_31[0][0]',
#  e)                                                                  'conv2d_transpose_10[0][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 112, 112, 64)         65600     ['activation_25[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 56, 56, 320)          0         ['activation_25[0][0]',
#  )                                                                   'conv2d_transpose_7[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 28, 28, 512)          4719104   ['concatenate_10[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 224, 224, 64)         32832     ['activation_21[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 112, 112, 192)        0         ['activation_21[0][0]',
#  )                                                                   'conv2d_transpose_5[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 56, 56, 64)           184384    ['concatenate_7[0][0]']
#
#  batch_normalization_40 (Ba  (None, 28, 28, 512)          2048      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  concatenate_4 (Concatenate  (None, 224, 224, 128)        0         ['activation_19[0][0]',
#  )                                                                   'conv2d_transpose_4[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 112, 112, 64)         110656    ['concatenate_5[0][0]']
#
#  batch_normalization_32 (Ba  (None, 56, 56, 64)           256       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 28, 28, 512)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 224, 224, 64)         73792     ['concatenate_4[0][0]']
#
#  batch_normalization_26 (Ba  (None, 112, 112, 64)         256       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 512)          2359808   ['activation_40[0][0]']
#
#  batch_normalization_22 (Ba  (None, 224, 224, 64)         256       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 56, 56, 64)           36928     ['activation_32[0][0]']
#
#  batch_normalization_41 (Ba  (None, 28, 28, 512)          2048      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 112, 112, 64)         36928     ['activation_26[0][0]']
#
#  batch_normalization_33 (Ba  (None, 56, 56, 64)           256       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 28, 28, 512)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 224, 224, 64)         36928     ['activation_22[0][0]']
#
#  batch_normalization_27 (Ba  (None, 112, 112, 64)         256       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_transpose_11 (Conv2  (None, 56, 56, 256)          524544    ['activation_41[0][0]']
#  DTranspose)
#
#  batch_normalization_23 (Ba  (None, 224, 224, 64)         256       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_transpose_8 (Conv2D  (None, 112, 112, 64)         16448     ['activation_33[0][0]']
#  Transpose)
#
#  concatenate_11 (Concatenat  (None, 56, 56, 576)          0         ['activation_25[0][0]',
#  e)                                                                  'activation_33[0][0]',
#                                                                      'conv2d_transpose_11[0][0]']
#
#  activation_23 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_transpose_6 (Conv2D  (None, 224, 224, 64)         16448     ['activation_27[0][0]']
#  Transpose)
#
#  concatenate_8 (Concatenate  (None, 112, 112, 256)        0         ['activation_21[0][0]',
#  )                                                                   'activation_27[0][0]',
#                                                                      'conv2d_transpose_8[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 56, 56, 256)          1327360   ['concatenate_11[0][0]']
#
#  concatenate_6 (Concatenate  (None, 224, 224, 192)        0         ['activation_19[0][0]',
#  )                                                                   'activation_23[0][0]',
#                                                                      'conv2d_transpose_6[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 112, 112, 64)         147520    ['concatenate_8[0][0]']
#
#  batch_normalization_42 (Ba  (None, 56, 56, 256)          1024      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  conv2d_29 (Conv2D)          (None, 224, 224, 64)         110656    ['concatenate_6[0][0]']
#
#  batch_normalization_34 (Ba  (None, 112, 112, 64)         256       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 56, 56, 256)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  batch_normalization_28 (Ba  (None, 224, 224, 64)         256       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 56, 56, 256)          590080    ['activation_42[0][0]']
#
#  activation_28 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 112, 112, 64)         36928     ['activation_34[0][0]']
#
#  batch_normalization_43 (Ba  (None, 56, 56, 256)          1024      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  conv2d_30 (Conv2D)          (None, 224, 224, 64)         36928     ['activation_28[0][0]']
#
#  batch_normalization_35 (Ba  (None, 112, 112, 64)         256       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 56, 56, 256)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  batch_normalization_29 (Ba  (None, 224, 224, 64)         256       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_transpose_12 (Conv2  (None, 112, 112, 128)        131200    ['activation_43[0][0]']
#  DTranspose)
#
#  activation_29 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_transpose_9 (Conv2D  (None, 224, 224, 64)         16448     ['activation_35[0][0]']
#  Transpose)
#
#  concatenate_12 (Concatenat  (None, 112, 112, 384)        0         ['activation_21[0][0]',
#  e)                                                                  'activation_27[0][0]',
#                                                                      'activation_35[0][0]',
#                                                                      'conv2d_transpose_12[0][0]']
#
#  concatenate_9 (Concatenate  (None, 224, 224, 256)        0         ['activation_19[0][0]',
#  )                                                                   'activation_23[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'conv2d_transpose_9[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 112, 112, 128)        442496    ['concatenate_12[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 224, 224, 64)         147520    ['concatenate_9[0][0]']
#
#  batch_normalization_44 (Ba  (None, 112, 112, 128)        512       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 224, 224, 64)         256       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 112, 112, 128)        0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 112, 112, 128)        147584    ['activation_44[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 224, 224, 64)         36928     ['activation_36[0][0]']
#
#  batch_normalization_45 (Ba  (None, 112, 112, 128)        512       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 224, 224, 64)         256       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 112, 112, 128)        0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_transpose_13 (Conv2  (None, 224, 224, 64)         32832     ['activation_45[0][0]']
#  DTranspose)
#
#  concatenate_13 (Concatenat  (None, 224, 224, 320)        0         ['activation_19[0][0]',
#  e)                                                                  'activation_23[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'activation_37[0][0]',
#                                                                      'conv2d_transpose_13[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 224, 224, 64)         184384    ['concatenate_13[0][0]']
#
#  batch_normalization_46 (Ba  (None, 224, 224, 64)         256       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 224, 224, 64)         36928     ['activation_46[0][0]']
#
#  batch_normalization_47 (Ba  (None, 224, 224, 64)         256       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 224, 224, 64)         0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 224, 224, 6)          390       ['activation_47[0][0]']
#
# ==================================================================================================
# Total params: 32739206 (124.89 MB)
# Trainable params: 32725894 (124.84 MB)
# Non-trainable params: 13312 (52.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ### (4) 모델 학습

# %% [markdown]
# 모델 성능 비교를 위해 총 4가지 모델을 생성하였다.
# 1. U-Net epoch 150 w.o hist equalize
# 2. U-Net epoch 150 w hist equalize
# 3. U-Net++ epoch 150 w.o hist equalize
# 4. U-Net++ epoch 150 w hist equalize

# %% [markdown]
# 아래의 코드는 모델 학습 과정을 나타내는 코드일 뿐이고 실제 학습은 각각 진행되었다.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam

def model_fit(model, epochs=150):
    checkpoint_callback = ModelCheckpoint(
        filepath=f'{model.name}_best_model.h5',
        monitor='val_loss',
        save_best_only=True,
        save_weights_only=False,
        mode='min'
    )

    model.compile(optimizer = Adam(1e-4), loss = 'binary_crossentropy', metrics=['accuracy'])

    return model.fit(
        train_data_generator,
        validation_data=test_data_generator,
        steps_per_epoch=len(train_data_generator),
        callbacks=[checkpoint_callback],
        epochs=epochs
    )

# %%
hist_unet = model_fit(model_unet)
# Out:
# Epoch 1/150
# 32/32 [==============================] - ETA: 0s - loss: 0.6701 - accuracy: 0.6170
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 32/32 [==============================] - 73s 2s/step - loss: 0.6701 - accuracy: 0.6170 - val_loss: 0.6817 - val_accuracy: 0.6395
# Epoch 2/150
# 32/32 [==============================] - 61s 2s/step - loss: 0.4765 - accuracy: 0.8312 - val_loss: 0.6210 - val_accuracy: 0.8311
# Epoch 3/150
# 32/32 [==============================] - 62s 2s/step - loss: 0.4571 - accuracy: 0.8327 - val_loss: 0.5918 - val_accuracy: 0.8327
# Epoch 4/150
# 32/32 [==============================] - 58s 2s/step - loss: 0.4542 - accuracy: 0.8328 - val_loss: 0.5479 - val_accuracy: 0.8327
# Epoch 5/150
# 32/32 [==============================] - 65s 2s/step - loss: 0.4534 - accuracy: 0.8328 - val_loss: 0.5151 - val_accuracy: 0.8327
# Epoch 6/150
# 32/32 [==============================] - 64s 2s/step - loss: 0.4528 - accuracy: 0.8328 - val_loss: 0.4912 - val_accuracy: 0.8327
# Epoch 7/150
# 32/32 [==============================] - 67s 2s/step - loss: 0.4524 - accuracy: 0.8328 - val_loss: 0.4745 - val_accuracy: 0.8327
# Epoch 8/150
# 32/32 [==============================] - 63s 2s/step - loss: 0.4523 - accuracy: 0.8328 - val_loss: 0.4666 - val_accuracy: 0.8327
# Epoch 9/150
# 32/32 [==============================] - 67s 2s/step - loss: 0.4523 - accuracy: 0.8328 - val_loss: 0.4601 - val_accuracy: 0.8327
# Epoch 10/150
# 32/32 [==============================] - 66s 2s/step - loss: 0.4522 - accuracy: 0.8328 - val_loss: 0.4573 - val_accuracy: 0.8327
# Epoch 11/150
# 32/32 [==============================] - 63s 2s/step - loss: 0.4521 - accuracy: 0.8328 - val_loss: 0.4551 - val_accuracy: 0.8327
# Epoch 12/150
# 32/32 [==============================] - 62s 2s/step - loss: 0.4520 - accuracy: 0.8328 - val_loss: 0.4544 - val_accuracy: 0.8327
# Epoch 13/150
# 32/32 [==============================] - 65s 2s/step - loss: 0.4521 - accuracy: 0.8328 - val_loss: 0.4532 - val_accuracy: 0.8327
# Epoch 14/150
# 32/32 [==============================] - 63s 2s/step - loss: 0.4520 - accuracy: 0.8328 - val_loss: 0.4528 - val_accuracy: 0.8327
# Epoch 15/150
# 32/32 [==============================] - 64s 2s/step - loss: 0.4519 - accuracy: 0.8328 - val_loss: 0.4525 - val_accuracy: 0.8327
# Epoch 16/150
# 32/32 [==============================] - 65s 2s/step - loss: 0.4519 - accuracy: 0.8328 - val_loss: 0.4524 - val_accuracy: 0.8327
# Epoch 17/150
# 32/32 [==============================] - 65s 2s/step - loss: 0.4518 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8327
# Epoch 18/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4518 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8327
# Epoch 19/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4517 - accuracy: 0.8328 - val_loss: 0.4527 - val_accuracy: 0.8327
# Epoch 20/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4517 - accuracy: 0.8328 - val_loss: 0.4528 - val_accuracy: 0.8327
# Epoch 21/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4517 - accuracy: 0.8328 - val_loss: 0.4524 - val_accuracy: 0.8327
# Epoch 22/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4517 - accuracy: 0.8328 - val_loss: 0.4557 - val_accuracy: 0.8327
# Epoch 23/150
# 32/32 [==============================] - 62s 2s/step - loss: 0.4517 - accuracy: 0.8328 - val_loss: 0.4520 - val_accuracy: 0.8327
# Epoch 24/150
# 32/32 [==============================] - 62s 2s/step - loss: 0.4517 - accuracy: 0.8328 - val_loss: 0.4520 - val_accuracy: 0.8327
# Epoch 25/150
# 32/32 [==============================] - 66s 2s/step - loss: 0.4517 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 26/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4516 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8327
# Epoch 27/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4516 - accuracy: 0.8328 - val_loss: 0.4531 - val_accuracy: 0.8327
# Epoch 28/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4516 - accuracy: 0.8328 - val_loss: 0.4522 - val_accuracy: 0.8327
# Epoch 29/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4516 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 30/150
# 32/32 [==============================] - 63s 2s/step - loss: 0.4515 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 31/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4514 - accuracy: 0.8328 - val_loss: 0.4547 - val_accuracy: 0.8326
# Epoch 32/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4514 - accuracy: 0.8328 - val_loss: 0.4564 - val_accuracy: 0.8327
# Epoch 33/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4513 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8326
# Epoch 34/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4513 - accuracy: 0.8328 - val_loss: 0.4601 - val_accuracy: 0.8305
# Epoch 35/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4513 - accuracy: 0.8328 - val_loss: 0.4581 - val_accuracy: 0.8327
# Epoch 36/150
# 32/32 [==============================] - 52s 2s/step - loss: 0.4514 - accuracy: 0.8328 - val_loss: 0.4833 - val_accuracy: 0.8213
# Epoch 37/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4514 - accuracy: 0.8328 - val_loss: 0.4890 - val_accuracy: 0.8156
# Epoch 38/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4532 - accuracy: 0.8328 - val_loss: 0.4658 - val_accuracy: 0.8301
# Epoch 39/150
# 32/32 [==============================] - 65s 2s/step - loss: 0.4521 - accuracy: 0.8328 - val_loss: 0.4555 - val_accuracy: 0.8327
# Epoch 40/150
# 32/32 [==============================] - 63s 2s/step - loss: 0.4518 - accuracy: 0.8328 - val_loss: 0.4750 - val_accuracy: 0.8213
# Epoch 41/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4517 - accuracy: 0.8328 - val_loss: 0.4590 - val_accuracy: 0.8304
# Epoch 42/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4515 - accuracy: 0.8328 - val_loss: 0.4558 - val_accuracy: 0.8327
# Epoch 43/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4514 - accuracy: 0.8328 - val_loss: 0.4524 - val_accuracy: 0.8327
# Epoch 44/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4514 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8327
# Epoch 45/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4514 - accuracy: 0.8328 - val_loss: 0.4521 - val_accuracy: 0.8327
# Epoch 46/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4513 - accuracy: 0.8328 - val_loss: 0.4520 - val_accuracy: 0.8327
# Epoch 47/150
# 32/32 [==============================] - 61s 2s/step - loss: 0.4514 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 48/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4513 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 49/150
# 32/32 [==============================] - 67s 2s/step - loss: 0.4513 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 50/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4513 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 51/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4513 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 52/150
# 32/32 [==============================] - 67s 2s/step - loss: 0.4513 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 53/150
# 32/32 [==============================] - 62s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 54/150
# 32/32 [==============================] - 66s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 55/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4527 - val_accuracy: 0.8327
# Epoch 56/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 57/150
# 32/32 [==============================] - 62s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 58/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4525 - val_accuracy: 0.8327
# Epoch 59/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 60/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4520 - val_accuracy: 0.8327
# Epoch 61/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 62/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4522 - val_accuracy: 0.8327
# Epoch 63/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 64/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 65/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 66/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 67/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 68/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8327
# Epoch 69/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4512 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 70/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 71/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4520 - val_accuracy: 0.8327
# Epoch 72/150
# 32/32 [==============================] - 62s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 73/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4520 - val_accuracy: 0.8327
# Epoch 74/150
# 32/32 [==============================] - 65s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4514 - val_accuracy: 0.8327
# Epoch 75/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4520 - val_accuracy: 0.8327
# Epoch 76/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4521 - val_accuracy: 0.8326
# Epoch 77/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 78/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4522 - val_accuracy: 0.8327
# Epoch 79/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 80/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 81/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4522 - val_accuracy: 0.8327
# Epoch 82/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 83/150
# 32/32 [==============================] - 61s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4514 - val_accuracy: 0.8327
# Epoch 84/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 85/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 86/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4520 - val_accuracy: 0.8327
# Epoch 87/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4521 - val_accuracy: 0.8327
# Epoch 88/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 89/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4517 - val_accuracy: 0.8327
# Epoch 90/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 91/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 92/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 93/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 94/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 95/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 96/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4526 - val_accuracy: 0.8327
# Epoch 97/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4535 - val_accuracy: 0.8325
# Epoch 98/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8327
# Epoch 99/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8327
# Epoch 100/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 101/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 102/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 103/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4519 - val_accuracy: 0.8327
# Epoch 104/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4535 - val_accuracy: 0.8326
# Epoch 105/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 106/150
# 32/32 [==============================] - 64s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4518 - val_accuracy: 0.8327
# Epoch 107/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4514 - val_accuracy: 0.8327
# Epoch 108/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 109/150
# 32/32 [==============================] - 71s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4514 - val_accuracy: 0.8327
# Epoch 110/150
# 32/32 [==============================] - 65s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 111/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 112/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4522 - val_accuracy: 0.8327
# Epoch 113/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4521 - val_accuracy: 0.8327
# Epoch 114/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 115/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4521 - val_accuracy: 0.8327
# Epoch 116/150
# 32/32 [==============================] - 57s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4514 - val_accuracy: 0.8327
# Epoch 117/150
# 32/32 [==============================] - 58s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 118/150
# 32/32 [==============================] - 57s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4514 - val_accuracy: 0.8327
# Epoch 119/150
# 32/32 [==============================] - 57s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4522 - val_accuracy: 0.8322
# Epoch 120/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 121/150
# 32/32 [==============================] - 64s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4513 - val_accuracy: 0.8327
# Epoch 122/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8327
# Epoch 123/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4522 - val_accuracy: 0.8327
# Epoch 124/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4545 - val_accuracy: 0.8326
# Epoch 125/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4524 - val_accuracy: 0.8327
# Epoch 126/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4523 - val_accuracy: 0.8318
# Epoch 127/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4522 - val_accuracy: 0.8327
# Epoch 128/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4633 - val_accuracy: 0.8327
# Epoch 129/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4526 - val_accuracy: 0.8327
# Epoch 130/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 131/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 132/150
# 32/32 [==============================] - 66s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4513 - val_accuracy: 0.8327
# Epoch 133/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4530 - val_accuracy: 0.8327
# Epoch 134/150
# 32/32 [==============================] - 56s 2s/step - loss: 0.4511 - accuracy: 0.8328 - val_loss: 0.4514 - val_accuracy: 0.8327
# Epoch 135/150
# 32/32 [==============================] - 68s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4513 - val_accuracy: 0.8327
# Epoch 136/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 137/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 138/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4522 - val_accuracy: 0.8327
# Epoch 139/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4520 - val_accuracy: 0.8327
# Epoch 140/150
# 32/32 [==============================] - 64s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4513 - val_accuracy: 0.8327
# Epoch 141/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4568 - val_accuracy: 0.8325
# Epoch 142/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4521 - val_accuracy: 0.8326
# Epoch 143/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4516 - val_accuracy: 0.8327
# Epoch 144/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4514 - val_accuracy: 0.8327
# Epoch 145/150
# 32/32 [==============================] - 64s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4519 - val_accuracy: 0.8327
# Epoch 146/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4535 - val_accuracy: 0.8327
# Epoch 147/150
# 32/32 [==============================] - 54s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4515 - val_accuracy: 0.8327
# Epoch 148/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.6081 - val_accuracy: 0.7845
# Epoch 149/150
# 32/32 [==============================] - 53s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4524 - val_accuracy: 0.8326
# Epoch 150/150
# 32/32 [==============================] - 55s 2s/step - loss: 0.4510 - accuracy: 0.8328 - val_loss: 0.4578 - val_accuracy: 0.8287

# %% [markdown]
# - 학습 결과 시각화(Ex. U-Net epoch 100)

# %%
plt.figure(figsize=(12, 6))

# train, validation loss graph
plt.subplot(1, 2, 1)
plt.plot(hist_unet.history['loss'])
plt.plot(hist_unet.history['val_loss'])
plt.title('U-Net Model Losses')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(1, 2, 2)
plt.plot(hist_unet.history['accuracy'])
plt.plot(hist_unet.history['val_accuracy'])
plt.title('U-Net Model accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper right')

# %% [markdown]
# - 모델 저장(Ex. U-Net epoch 100)

# %%
model_unet.save('./models/unet_epoch_150.h5')

# %% [markdown]
# - history 저장(Ex. U-Net epoch 100)

# %%
# convert the history.history dict to a pandas DataFrame:
import pandas as pd
hist_df = pd.DataFrame(hist_unet.history)

# save to json:
hist_json_file = 'unet_epoch_150_history.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %% [markdown]
# ### (5) Prediction 결과 비교

# %% [markdown]
# 학습된 4개의 모델을 먼저 불러온다.

# %%
MODEL_PATH = './models/'
model_file_list = ['unet_epoch_150.h5', 'unetpp_epoch_150.h5', 'unetpp_aug_epoch_150.h5', 'unetpp_hist_epoch_150.h5']

# %%
model_unet_150 = models.load_model(MODEL_PATH + model_file_list[0])
model_unetpp_150 = models.load_model(MODEL_PATH + model_file_list[1])
model_unetpp_aug_150 = models.load_model(MODEL_PATH + model_file_list[2])
model_unetpp_hist_150 = models.load_model(MODEL_PATH + model_file_list[3])

# %%
model_dict = {
    'U-Net epoch 150' : model_unet_150,
    'U-Net++ epoch 150' : model_unetpp_150,
    'U-Net++ epoch 150 w aug' : model_unetpp_aug_150,
    'U-Net++ epoch 150 w hist' : model_unetpp_hist_150,
}

# %% [markdown]
# - Segmentation 시각화를 위한 colormap 설정

# %%
colormap = [
    [65, 117, 6],
    [74, 114, 226],
    [57, 234, 92],
    [248, 231, 28],
    [155, 155, 155],
    [254, 166, 35]
]

# %% [markdown]
# - 모델 prediction 결과 시각화

# %%
def get_output(models, origin_img, label_img, colormap=colormap, preproc=test_preproc):
    fig_len = len(models) + 2
    plt.figure(figsize=(3 * fig_len, 3))

    plt.subplot(1, fig_len, 1)
    plt.title('Origin Image')
    plt.axis('off')
    plt.imshow(origin_img)                          # Origin Image

    for idx, (name, m) in enumerate(models.items()):
        pred = m(np.expand_dims(origin_img,axis=0))
        segment = np.argmax(pred, axis=3)           # 픽셀별로 가장 높은 class로 설정

        output = np.zeros((segment.shape[1], segment.shape[2], 3))

        for i in range(output.shape[0]):
            for j in range(output.shape[1]):
                output[i][j] = colormap[segment[0][i][j]]  # color 입히기

        output = tf.cast(output, tf.uint8)

        plt.subplot(1, fig_len, idx + 2)
        plt.title(f'{name}')
        plt.axis('off')
        plt.imshow(output)                          # Model Prediction Image

    origin_label = np.zeros((label_img.shape[0], label_img.shape[1], 3))

    for idx, label in enumerate(np.transpose(label_img, (2, 0, 1))):
        for i in range(label.shape[0]):
            for j in range(label.shape[1]):
                if label[i][j] == 1.:
                    origin_label[i][j] = colormap[idx]

    origin_label = tf.cast(origin_label, tf.uint8)

    plt.subplot(1, fig_len, fig_len)
    plt.title('Ground Truth')
    plt.axis('off')
    plt.imshow(origin_label)                        # Ground Truth Mask

    plt.show()

# %%
for epoch in range(1):
    for batch_data, batch_masks in test_data_generator:
        for i in range(batch_size):
            get_output(model_dict, batch_data[i], batch_masks[i])

        break

# %% [markdown]
# ### (6) IoU 성능 비교

# %% [markdown]
# - Intersection over Union

# %%
def calculate_iou_score(targets, predictions, classes=class_id_to_name):
    iou_scores = []
    intersections = []
    unions = []

    for i, (_, name) in enumerate(classes.items()):
        intersection = np.logical_and(targets[i], predictions[i])       # 교집합 계산
        union = np.logical_or(targets[i], predictions[i])               # 합집합 계산
        iou_score = float(np.sum(intersection)) / float(np.sum(union))  # IoU 계산

        intersections.append(intersection)
        unions.append(union)
        iou_scores.append(iou_score)

        print(f'IoU of {name} : {iou_score:.4f}', end='    ')

    print(f'\nMean IoU : {np.mean(iou_scores):.4f}', end='    ')
    print(f'Pixel Accuracy : {np.sum(intersections) / np.sum(unions):.4f}\n')  # 최종 IoU

    return np.mean(iou_scores), np.sum(intersections) / np.sum(unions)

# %%
for epoch in range(1):
    for batch_data, batch_masks in test_data_generator:
        avg_iou_dict = {
            'U-Net epoch 150' : [],
            'U-Net++ epoch 150' : [],
            'U-Net++ epoch 150 w aug' : [],
            'U-Net++ epoch 150 w hist' : [],
        }
        avg_acc_dict = {
            'U-Net epoch 150' : [],
            'U-Net++ epoch 150' : [],
            'U-Net++ epoch 150 w aug' : [],
            'U-Net++ epoch 150 w hist' : [],
        }

        for idx in range(batch_size):
            print(f'Index {idx} of Batch')
            for n, m in model_dict.items():
                print(f'{n} IoUs')

                predictions = np.array(m(np.expand_dims(batch_data[idx], axis=0))[0])

                # 각 픽셀의 값을 1 또는 0으로 thresholding
                for i in range(predictions.shape[0]):
                    for j in range(predictions.shape[1]):
                        for k in range(predictions.shape[2]):
                            if predictions[i][j][k] >= 0.5:
                                predictions[i][j][k] = 1
                            else:
                                predictions[i][j][k] = 0

                mean_iou, pixel_acc = calculate_iou_score(np.transpose(batch_masks[idx], (2, 0, 1)), np.transpose(predictions, (2, 0, 1)))

                avg_iou_dict[n].append(mean_iou)
                avg_acc_dict[n].append(pixel_acc)

            print()

        for k in avg_iou_dict.keys():
            print(f'{k} average mIoU : {np.mean(avg_iou_dict[k]):.4f} \t average pAcc : {np.mean(avg_acc_dict[k]):.4f}')

        break
# Out:
# Index 0 of Batch
# U-Net epoch 150 IoUs
# IoU of Rider : 0.9425    IoU of My bike : 0.9175    IoU of Moveable : 0.1107    IoU of Lane Mark : 0.2183    IoU of Road : 0.8877    IoU of Undrivable : 0.9472
# Mean IoU : 0.6706    Pixel Accuracy : 0.8891
#
# U-Net++ epoch 150 IoUs
# IoU of Rider : 0.9722    IoU of My bike : 0.9737    IoU of Moveable : 0.5882    IoU of Lane Mark : 0.2572    IoU of Road : 0.9154    IoU of Undrivable : 0.9570
# Mean IoU : 0.7773    Pixel Accuracy : 0.9291
#
# U-Net++ epoch 150 w aug IoUs
# IoU of Rider : 0.8866    IoU of My bike : 0.8802    IoU of Moveable : 0.3265    IoU of Lane Mark : 0.0000    IoU of Road : 0.6797    IoU of Undrivable : 0.9538
# Mean IoU : 0.6211    Pixel Accuracy : 0.8248
#
# U-Net++ epoch 150 w hist IoUs
# IoU of Rider : 0.9264    IoU of My bike : 0.8984    IoU of Moveable : 0.2061    IoU of Lane Mark : 0.1191    IoU of Road : 0.5984    IoU of Undrivable : 0.9519
# Mean IoU : 0.6167    Pixel Accuracy : 0.7771
#
#
# Index 1 of Batch
# U-Net epoch 150 IoUs
# IoU of Rider : 0.8927    IoU of My bike : 0.9177    IoU of Moveable : 0.0000    IoU of Lane Mark : 0.3977    IoU of Road : 0.7609    IoU of Undrivable : 0.7870
# Mean IoU : 0.6260    Pixel Accuracy : 0.7521
#
# U-Net++ epoch 150 IoUs
# IoU of Rider : 0.9567    IoU of My bike : 0.9541    IoU of Moveable : 0.0822    IoU of Lane Mark : 0.5169    IoU of Road : 0.8403    IoU of Undrivable : 0.7984
# Mean IoU : 0.6914    Pixel Accuracy : 0.7857
#
# U-Net++ epoch 150 w aug IoUs
# IoU of Rider : 0.9200    IoU of My bike : 0.8617    IoU of Moveable : 0.1186    IoU of Lane Mark : 0.0361    IoU of Road : 0.7101    IoU of Undrivable : 0.8029
# Mean IoU : 0.5749    Pixel Accuracy : 0.7376
#
# U-Net++ epoch 150 w hist IoUs
# IoU of Rider : 0.7144    IoU of My bike : 0.7680    IoU of Moveable : 0.0974    IoU of Lane Mark : 0.0000    IoU of Road : 0.3826    IoU of Undrivable : 0.7950
# Mean IoU : 0.4596    Pixel Accuracy : 0.5759
#
#
# Index 2 of Batch
# U-Net epoch 150 IoUs
# IoU of Rider : 0.9484    IoU of My bike : 0.8825    IoU of Moveable : 0.0090    IoU of Lane Mark : 0.5010    IoU of Road : 0.7629    IoU of Undrivable : 0.9429
# Mean IoU : 0.6745    Pixel Accuracy : 0.8347
#
# U-Net++ epoch 150 IoUs
# IoU of Rider : 0.9603    IoU of My bike : 0.9697    IoU of Moveable : 0.3638    IoU of Lane Mark : 0.6368    IoU of Road : 0.8157    IoU of Undrivable : 0.9092
# Mean IoU : 0.7759    Pixel Accuracy : 0.8617
#
# U-Net++ epoch 150 w aug IoUs
# IoU of Rider : 0.9213    IoU of My bike : 0.7890    IoU of Moveable : 0.0570    IoU of Lane Mark : 0.1187    IoU of Road : 0.5697    IoU of Undrivable : 0.8787
# Mean IoU : 0.5558    Pixel Accuracy : 0.7352
#
# U-Net++ epoch 150 w hist IoUs
# IoU of Rider : 0.8346    IoU of My bike : 0.8342    IoU of Moveable : 0.0605    IoU of Lane Mark : 0.0749    IoU of Road : 0.3220    IoU of Undrivable : 0.7948
# Mean IoU : 0.4868    Pixel Accuracy : 0.6445
#
#
# Index 3 of Batch
# U-Net epoch 150 IoUs
# IoU of Rider : 0.7959    IoU of My bike : 0.8750    IoU of Moveable : 0.0000    IoU of Lane Mark : 0.0970    IoU of Road : 0.3004    IoU of Undrivable : 0.8772
# Mean IoU : 0.4909    Pixel Accuracy : 0.8027
#
# U-Net++ epoch 150 IoUs
# IoU of Rider : 0.9107    IoU of My bike : 0.9438    IoU of Moveable : 0.0000    IoU of Lane Mark : 0.2851    IoU of Road : 0.4358    IoU of Undrivable : 0.8885
# Mean IoU : 0.5773    Pixel Accuracy : 0.8279
#
# U-Net++ epoch 150 w aug IoUs
# IoU of Rider : 0.8946    IoU of My bike : 0.8139    IoU of Moveable : 0.0000    IoU of Lane Mark : 0.1653    IoU of Road : 0.4816    IoU of Undrivable : 0.9195
# Mean IoU : 0.5458    Pixel Accuracy : 0.8512
#
# U-Net++ epoch 150 w hist IoUs
# IoU of Rider : 0.6609    IoU of My bike : 0.7600    IoU of Moveable : 0.0000    IoU of Lane Mark : 0.2354    IoU of Road : 0.3271    IoU of Undrivable : 0.7594
# Mean IoU : 0.4571    Pixel Accuracy : 0.6848
#
#
# Index 4 of Batch
# U-Net epoch 150 IoUs
# IoU of Rider : 0.8853    IoU of My bike : 0.8933    IoU of Moveable : 0.5789    IoU of Lane Mark : 0.1037    IoU of Road : 0.7919    IoU of Undrivable : 0.8299
# Mean IoU : 0.6805    Pixel Accuracy : 0.8095
#
# U-Net++ epoch 150 IoUs
# IoU of Rider : 0.9386    IoU of My bike : 0.9718    IoU of Moveable : 0.8075    IoU of Lane Mark : 0.4719    IoU of Road : 0.8717    IoU of Undrivable : 0.9036
# Mean IoU : 0.8275    Pixel Accuracy : 0.9003
#
# U-Net++ epoch 150 w aug IoUs
# IoU of Rider : 0.8435    IoU of My bike : 0.9291    IoU of Moveable : 0.4337    IoU of Lane Mark : 0.0928    IoU of Road : 0.7634    IoU of Undrivable : 0.7753
# Mean IoU : 0.6396    Pixel Accuracy : 0.7793
#
# U-Net++ epoch 150 w hist IoUs
# IoU of Rider : 0.8728    IoU of My bike : 0.8847    IoU of Moveable : 0.7417    IoU of Lane Mark : 0.1118    IoU of Road : 0.8471    IoU of Undrivable : 0.9175
# Mean IoU : 0.7293    Pixel Accuracy : 0.8704
#
#
# U-Net epoch 150 average mIoU : 0.6285 	 average pAcc : 0.8176
# U-Net++ epoch 150 average mIoU : 0.7299 	 average pAcc : 0.8609
# U-Net++ epoch 150 w aug average mIoU : 0.5874 	 average pAcc : 0.7856
# U-Net++ epoch 150 w hist average mIoU : 0.5499 	 average pAcc : 0.7105
